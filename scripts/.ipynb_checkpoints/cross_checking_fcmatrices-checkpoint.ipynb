# %% [markdown]
# ## Load packages

# %%
# General
import numpy as np
from numpy import inf
import pandas as pd
import os

# Computing
import scipy.io
import sklearn 

# Neuroimaging
import nibabel as nib
#from nilearn.connectome import ConnectivityMeasure  # use np.corrcoef
from nilearn.datasets import fetch_atlas_schaefer_2018
import hcp_utils as hcp

# %% [markdown]
# # Cross checking fc matrices HCP S1200 Schaefer
#
# Bin's matrices are 419x419 because they include subcortical areas, but the first 400 parcels should correspond to Sofie's and Bianca's 400x400 matrices

# %% [markdown]
# ## Loading Sofie's matlab data

# %%
scipy.io.whosmat('/data/p_02667/sex_diff_gradients/sofie/for_bianca.mat')
# Out:
# [('for_bianca', (1, 1), 'struct')]

# %%
# only taking the matrices from the mat file, and the corresponding subject using [0][0][n]
sub100206_sofie = scipy.io.loadmat('/data/p_02667/sex_diff_gradients/sofie/for_bianca.mat')['for_bianca'][0][0][0]
sub100307_sofie = scipy.io.loadmat('/data/p_02667/sex_diff_gradients/sofie/for_bianca.mat')['for_bianca'][0][0][1]
sub996782_sofie = scipy.io.loadmat('/data/p_02667/sex_diff_gradients/sofie/for_bianca.mat')['for_bianca'][0][0][2]

# %% [markdown]
# ## sub100206

# %%
sub100206_sofie = pd.DataFrame(sub100206_sofie[0])
sub100206_sofie
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.000000  0.247193  0.299148  0.301688  0.237693  0.133188  0.128982
# 1    0.247193  0.000000  0.139588  0.216277  0.181307  0.052357  0.172476
# 2    0.299148  0.139588  0.000000  0.369977  0.408109  0.401964  0.056572
# 3    0.301688  0.216277  0.369977  0.000000  0.425999  0.164726  0.135394
# 4    0.237693  0.181307  0.408109  0.425999  0.000000  0.235021  0.083619
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0.079523  0.049239  0.004820  0.016963 -0.018592  0.090751  0.097237
# 396  0.157998  0.155197  0.070179  0.101604  0.073230  0.190170  0.164712
# 397  0.067199  0.008895  0.141122  0.088887  0.079243  0.188538  0.079015
# 398  0.130007  0.097771  0.069954  0.078747  0.058810  0.091766  0.130681
# 399  0.172637  0.208689  0.185013  0.241466  0.167597  0.201060  0.169867
#
#           7         8         9    ...       390       391       392  \
# 0    0.287997  0.141514  0.209251  ...  0.108978  0.205448  0.018873
# 1    0.061780  0.124319  0.160618  ...  0.056861  0.257514 -0.041606
# 2    0.516155  0.299008  0.266655  ...  0.141505  0.101855  0.016529
# 3    0.320658  0.237543  0.375850  ...  0.136991  0.176976  0.007191
# 4    0.357014  0.374949  0.330427  ...  0.141634  0.116946 -0.011740
# ..        ...       ...       ...  ...       ...       ...       ...
# 395 -0.008551  0.104490 -0.017463  ...  0.071287  0.336232  0.107262
# 396  0.061385  0.222545  0.149839  ...  0.106252  0.565456  0.143068
# 397  0.162943  0.157695  0.094975  ...  0.144350  0.178200  0.144896
# 398  0.050390  0.131585  0.055267  ...  0.084132  0.389435  0.063042
# 399  0.153837  0.262166  0.296892  ...  0.091548  0.503190  0.103941
#
#           393       394       395       396       397       398       399
# 0    0.126632  0.051200  0.079523  0.157998  0.067199  0.130007  0.172637
# 1    0.197866  0.030079  0.049239  0.155197  0.008895  0.097771  0.208689
# 2    0.072855  0.012525  0.004820  0.070179  0.141122  0.069954  0.185013
# 3    0.107123 -0.032066  0.016963  0.101604  0.088887  0.078747  0.241466
# 4    0.090524 -0.011491 -0.018592  0.073230  0.079243  0.058810  0.167597
# ..        ...       ...       ...       ...       ...       ...       ...
# 395  0
# 4    0.025053  0.040970  0.167795  0.136287  0.174638  0.206798  0.214381
# ..        ...       ...       ...       ...       ...       ...       ...
# 414  0.072374  0.064424  0.000000  0.429341  0.228677  0.208400  0.206603
# 415  0.026931  0.103182  0.429341  0.000000  0.192943  0.222064  0.216841
# 416  0.042840  0.050054  0.228677  0.192943  0.000000  0.326307  0.273840
# 417  0.008880  0.065819  0.208400  0.222064  0.326307  0.000000  0.280757
# 418  0.025507  0.049753  0.206603  0.216841  0.273840  0.280757  0.000000
#
# [419 rows x 419 columns]

# %% [raw]
# # Understanding Bin's code to compute fc matrices
#
# Taking example of subject 100206

# %% [raw]
# ## Loading Schaefer 400 atlas (7 network) and adapting it to HCP data

# %% [raw]
# # Schaefer_400 - 7 networks
# dlabel_400 = nib.load('/data/p_02667/sex_diff_gradients/data/schaefer400/Schaefer2018_400Parcels_7Networks_order.dlabel.nii').get_fdata()
#
# # fs_LR_32k is a standard brain surface (like MNI space) -> LR means the first 32k belong to left hemisphere, the second belong to right hemisphere
# mat = scipy.io.loadmat('/data/p_02667/sex_diff_gradients/data/schaefer400/fs_LR_32k_medial_mask.mat')
#
#
# # HCP cortex data does not contain medial_wall using python, we need to delete it in Schaefer template
# mask = mat['medial_mask']
# schaefer_400 = dlabel_400.T[np.where(mask==1)]

# %% [raw]
# schaefer_400.max()

# %% [raw]
# ## Define directories

# %% [raw]
# codedir = os.path.abspath('')  # obtain current direction from which script is runnning
#
# datadir_day2 = '/data/p_02378/data/hcp_rsfunc/hcp-functional-connectivity/'
#
# datadir_day1 = '/data/p_02378/data/hcp_rsfunc/HCP_S1200_rfMRI_DAY1/'
#
# dataout = '/data/p_02667/sex_diff_gradients/data/fc_matrices/schaefer_output/'

# %% [raw]
# path_list = os.listdir(datadir_day2)
# path_list.sort()
#
# # DELETE THIS!! use np.corrcoef instead to get the same results as Sofie's matlab scripts
# #correlation_measure = ConnectivityMeasure(kind='correlation')

# %% [raw]
# path_list

# %% [raw]
# ## Scan session day 2 - LR

# %% [raw]
# # read the time series of scan session day 2, LR, ** rfMRI_REST2_LR **
# # parcellate the time series to Glasser 360 (hcp.parcellate(data, hcp.mmp)) and then adapte it to Schaefer
# # compute the functional connectivity matrix
#
#
# img = nib.load(datadir_day2+'100206'+'/MNINonLinear/Results/rfMRI_REST2_LR/rfMRI_REST2_LR_Atlas_MSMAll_hp2000_clean.dtseries.nii')
# data = img.get_fdata()
# data_parc = hcp.parcellate(data, hcp.mmp)
# data_sub = data_parc[:,360:]  # this is the subcortical regions parcels: include if you want 419x419 matrices
#
# img_cortex = data[:,hcp.struct.cortex] # cortex vertices
# node = [None]*400 # data_sub.shape[0] is time points. not all data has 1200 ts
#
# for i in range(400):
#     a = img_cortex[:,np.where(schaefer_400==i+1)][:,0]
#     ts = [None] * data_sub.shape[0]
#
#     for n in range(data_sub.shape[0]):
#         ts[n] = a[n].mean()
#         node[i] = ts
#
# # cortex parcels finished, now concatenate cortex and subcortex
# data_cor = np.array(node)
#
# # if you want matrices to include cortical and subcortical regions parcels, concatenate them here (so that in 419x419 matrices, the last 19 are subcortical parcels)
# data_cor_sub = np.concatenate((data_cor,data_sub.T))
#
# # correlation
# corr_matrix_day2_LR_bin = np.corrcoef(data_cor_sub)   # use data_cor_sub if I want to include subcortical areas to yield 419x419 matrices
# corr_matrix_day2_LR_bin

# %% [raw]
# ## Scan session day 2 - RL

# %% [raw]
# # read the time series of scan session day 2, RL, ** rfMRI_REST2_RL **
# # parcellate the time series to Glasser 360 (hcp.parcellate(data, hcp.mmp)) and then adapte it to Schaefer
# # compute the functional connectivity matrix
#
# img = nib.load(datadir_day2+'100206'+'/MNINonLinear/Results/rfMRI_REST2_RL/rfMRI_REST2_RL_Atlas_MSMAll_hp2000_clean.dtseries.nii')
# data = img.get_fdata()
# data_parc = hcp.parcellate(data, hcp.mmp)
# data_sub = data_parc[:,360:]  # this is the subcortical regions parcels: include if you want 419x419 matrices
#
# img_cortex = data[:,hcp.struct.cortex] # cortex vertices
# node = [None]*400 # data_sub.shape[0] is time points. not all data has 1200 ts
#
# for i in range(400):
#     a = img_cortex[:,np.where(schaefer_400==i+1)][:,0]
#     ts = [None] * data_sub.shape[0]
#
#     for n in range(data_sub.shape[0]):
#         ts[n] = a[n].mean()
#         node[i] = ts
#
# # cortex parcels finished, now concatenate cortex and subcortex
# data_cor = np.array(node)
#
# # if you want matrices to include cortical and subcortical regions parcels, concatenate them here (so that in 419x419 matrices, the last 19 are subcortical parcels)
# data_cor_sub = np.concatenate((data_cor,data_sub.T))
#
# # correlation
# corr_matrix_day2_RL_bin = np.corrcoef(data_cor_sub)  # use data_cor_sub if I want to include subcortical areas to yield 419x419 matrices
# corr_matrix_day2_RL_bin

# %% [raw]
# ## Scan session day 1 - LR

# %% [raw]
# # read the time series of scan session day 1, LR, ** rfMRI_REST1_LR **,
# # parcellate the time series to Glasser 360 (hcp.parcellate(data, hcp.mmp)) and then adapte it to Schaefer
# # compute the functional connectivity matrix
#
#
# img = nib.load(datadir_day1+'100206'+'/MNINonLinear/Results/rfMRI_REST1_LR/rfMRI_REST1_LR_Atlas_MSMAll_hp2000_clean.dtseries.nii')
# data = img.get_fdata()
# data_parc = hcp.parcellate(data, hcp.mmp)
# data_sub = data_parc[:,360:]  # this is the subcortical regions parcels: include if you want 419x419 matrices
#
# img_cortex = data[:,hcp.struct.cortex] # cortex vertices
# node = [None]*400 # data_sub.shape[0] is time points. not all data has 1200 ts
#
# for i in range(400):
#     a = img_cortex[:,np.where(schaefer_400==i+1)][:,0]
#     ts = [None] * data_sub.shape[0]
#
#     for n in range(data_sub.shape[0]):
#         ts[n] = a[n].mean()
#         node[i] = ts
#
# # cortex parcels finished, now concatenate cortex and subcortex
# data_cor = np.array(node)
#
# # if you want matrices to include cortical and subcortical regions parcels, concatenate them here (so that in 419x419 matrices, the last 19 are subcortical parcels)
# data_cor_sub = np.concatenate((data_cor,data_sub.T))
#
# # correlation
# corr_matrix_day1_LR_bin = np.corrcoef(data_cor_sub)  # use data_cor_sub if I want to include subcortical areas to yield 419x419 matrices
# corr_matrix_day1_LR_bin

# %% [raw]
# ## Scan session day 1 - RL

# %% [raw]
# # read the time series of scan session day 1, RL, ** rfMRI_REST1_RL **,
# # parcellate the time series to Glasser 360 (hcp.parcellate(data, hcp.mmp)) and then adapte it to Schaefer
# # compute the functional connectivity matrix
#
# img = nib.load(datadir_day1+'100206'+'/MNINonLinear/Results/rfMRI_REST1_RL/rfMRI_REST1_RL_Atlas_MSMAll_hp2000_clean.dtseries.nii')
# data = img.get_fdata()
# data_parc = hcp.parcellate(data, hcp.mmp)
# data_sub = data_parc[:,360:]  # this is the subcortical regions parcels: include if you want 419x419 matrices
#
# img_cortex = data[:,hcp.struct.cortex] # cortex vertices
# node = [None]*400 # data_sub.shape[0] is time points. not all data has 1200 ts
#
# for i in range(400):
#     a = img_cortex[:,np.where(schaefer_400==i+1)][:,0]
#     ts = [None] * data_sub.shape[0]
#
#     for n in range(data_sub.shape[0]):
#         ts[n] = a[n].mean()
#         node[i] = ts
#
# # cortex parcels finished, now concatenate cortex and subcortex
# data_cor = np.array(node)
#
# # if you want matrices to include cortical and subcortical regions parcels, concatenate them here (so that in 419x419 matrices, the last 19 are subcortical parcels)
# data_cor_sub = np.concatenate((data_cor,data_sub.T))
#
# # correlation
# corr_matrix_day1_RL_bin = np.corrcoef(data_cor_sub)  # use data_cor_sub if I want to include subcortical areas to yield 419x419 matrices
# corr_matrix_day1_RL_bin

# %% [raw]
# ## Average functional connectivity and z-transform them across the 4 sessions

# %% [raw]
# # (across rfMRI_REST1_LR, rfMRI_REST1_RL, rfMRI_REST2_LR, rfMRI_REST2_RL)
#
# LR1_bin = corr_matrix_day1_LR_bin
# RL1_bin = corr_matrix_day1_RL_bin
# LR2_bin = corr_matrix_day2_LR_bin
# RL2_bin = corr_matrix_day2_RL_bin
#
# # average across four sessions
# mean_bin = (LR1_bin+RL1_bin+LR2_bin+RL2_bin)/4
#
# # Fisher r to z transform
# fc_bin = np.arctanh(mean_bin[:400,:400])  # only taking the first 400 parcels (given that full matrices include subcortical areas (419x419)
# fc_bin[fc_bin == inf] = 0
# fc_bin
# pd.DataFrame(fc_bin)

# %% [raw]
# # How Bianca computed fc matrices
# #### Only differences with Bin's code:
# - comment out data_cor_sub = np.concatenate((data_cor,data_sub.T))
# - didn't run correlation (to obtain correlation matrices) on data_cor_sub but on data_cor_sub (without subcortical areas)
#
# Taking example of subject 100206

# %% [raw]
# ## Loading Schaefer 400 atlas (7 network) and adapting it to HCP data

# %% [raw]
# # Schaefer_400 - 7 networks
# dlabel_400 = nib.load('/data/p_02667/sex_diff_gradients/data/schaefer400/Schaefer2018_400Parcels_7Networks_order.dlabel.nii').get_fdata()
#
# # fs_LR_32k is a standard brain surface (like MNI space) -> LR means the first 32k belong to left hemisphere, the second belong to right hemisphere
# mat = scipy.io.loadmat('/data/p_02667/sex_diff_gradients/data/schaefer400/fs_LR_32k_medial_mask.mat')
#
#
# # HCP cortex data does not contain medial_wall using python, we need to delete it in Schaefer template
# mask = mat['medial_mask']
# schaefer_400 = dlabel_400.T[np.where(mask==1)]

# %% [raw]
# ## Define directories

# %% [raw]
# codedir = os.path.abspath('')  # obtain current direction from which script is runnning
#
# datadir_day2 = '/data/p_02378/data/hcp_rsfunc/hcp-functional-connectivity/'
#
# datadir_day1 = '/data/p_02378/data/hcp_rsfunc/HCP_S1200_rfMRI_DAY1/'
#
# dataout = '/data/p_02667/sex_diff_gradients/data/fc_matrices/schaefer_output/'

# %% [raw]
# path_list = os.listdir(datadir_day2)
# path_list.sort()
#
# # DELETE THIS!! use np.corrcoef instead to get the same results as Sofie's matlab scripts
# #correlation_measure = ConnectivityMeasure(kind='correlation')

# %% [raw]
# path_list

# %% [raw]
# ## Scan session day 2 - LR

# %% [raw]
# # read the time series of scan session day 2, LR, ** rfMRI_REST2_LR **
# # parcellate the time series to Glasser 360 (hcp.parcellate(data, hcp.mmp)) and then adapte it to Schaefer
# # compute the functional connectivity matrix
#
#
# img = nib.load(datadir_day2+'100206'+'/MNINonLinear/Results/rfMRI_REST2_LR/rfMRI_REST2_LR_Atlas_MSMAll_hp2000_clean.dtseries.nii')
# data = img.get_fdata()
# # data_parc = hcp.parcellate(data, hcp.mmp)
# # data_sub = data_parc[:,360:]  # this is the subcortical regions parcels: include if you want 419x419 matrices
#
# img_cortex = data[:,hcp.struct.cortex] # cortex vertices
# node = [None]*400 # data_sub.shape[0] is time points. not all data has 1200 ts
#
# for i in range(400):
#     a = img_cortex[:,np.where(schaefer_400==i+1)][:,0]
#     ts = [None] * 1200
#
#     for n in range(1200):
#         ts[n] = a[n].mean()
#         node[i] = ts
#
# # cortex parcels finished, now concatenate cortex and subcortex
# data_cor = np.array(node)
#
# # if you want matrices to include cortical and subcortical regions parcels, concatenate them here (so that in 419x419 matrices, the last 19 are subcortical parcels)
# #data_cor_sub = np.concatenate((data_cor,data_sub.T))
#
# # correlation
# corr_matrix_day2_LR_bianca = np.corrcoef(data_cor)   # use data_cor_sub if I want to include subcortical areas to yield 419x419 matrices
# pd.DataFrame(corr_matrix_day2_LR_bianca)

# %% [raw]
# ## Scan session day 2 - RL

# %% [raw]
# # read the time series of scan session day 2, RL, ** rfMRI_REST2_RL **
# # parcellate the time series to Glasser 360 (hcp.parcellate(data, hcp.mmp)) and then adapte it to Schaefer
# # compute the functional connectivity matrix
#
# img = nib.load(datadir_day2+'100206'+'/MNINonLinear/Results/rfMRI_REST2_RL/rfMRI_REST2_RL_Atlas_MSMAll_hp2000_clean.dtseries.nii')
# data = img.get_fdata()
# data_parc = hcp.parcellate(data, hcp.mmp)
# data_sub = data_parc[:,360:]  # this is the subcortical regions parcels: include if you want 419x419 matrices
#
# img_cortex = data[:,hcp.struct.cortex] # cortex vertices
# node = [None]*400 # data_sub.shape[0] is time points. not all data has 1200 ts
#
# for i in range(400):
#     a = img_cortex[:,np.where(schaefer_400==i+1)][:,0]
#     ts = [None] * data_sub.shape[0]
#
#     for n in range(data_sub.shape[0]):
#         ts[n] = a[n].mean()
#         node[i] = ts
#
# # cortex parcels finished, now concatenate cortex and subcortex
# data_cor = np.array(node)
#
# # if you want matrices to include cortical and subcortical regions parcels, concatenate them here (so that in 419x419 matrices, the last 19 are subcortical parcels)
# #data_cor_sub = np.concatenate((data_cor,data_sub.T))
#
# # correlation
# corr_matrix_day2_RL_bianca = np.corrcoef(data_cor)  # use data_cor_sub if I want to include subcortical areas to yield 419x419 matrices
# pd.DataFrame(corr_matrix_day2_RL_bianca)

# %% [raw]
# ## Scan session day 1 - LR

# %% [raw]
# # read the time series of scan session day 1, LR, ** rfMRI_REST1_LR **,
# # parcellate the time series to Glasser 360 (hcp.parcellate(data, hcp.mmp)) and then adapte it to Schaefer
# # compute the functional connectivity matrix
#
#
# img = nib.load(datadir_day1+'100206'+'/MNINonLinear/Results/rfMRI_REST1_LR/rfMRI_REST1_LR_Atlas_MSMAll_hp2000_clean.dtseries.nii')
# data = img.get_fdata()
# data_parc = hcp.parcellate(data, hcp.mmp)
# data_sub = data_parc[:,360:]  # this is the subcortical regions parcels: include if you want 419x419 matrices
#
# img_cortex = data[:,hcp.struct.cortex] # cortex vertices
# node = [None]*400 # data_sub.shape[0] is time points. not all data has 1200 ts
#
# for i in range(400):
#     a = img_cortex[:,np.where(schaefer_400==i+1)][:,0]
#     ts = [None] * data_sub.shape[0]
#
#     for n in range(data_sub.shape[0]):
#         ts[n] = a[n].mean()
#         node[i] = ts
#
# # cortex parcels finished, now concatenate cortex and subcortex
# data_cor = np.array(node)
#
# # if you want matrices to include cortical and subcortical regions parcels, concatenate them here (so that in 419x419 matrices, the last 19 are subcortical parcels)
# #data_cor_sub = np.concatenate((data_cor,data_sub.T))
#
# # correlation
# corr_matrix_day1_LR_bianca = np.corrcoef(data_cor)  # use data_cor_sub if I want to include subcortical areas to yield 419x419 matrices
# pd.DataFrame(corr_matrix_day1_LR_bianca)

# %% [raw]
# ## Scan session day 1 - RL

# %% [raw]
# # read the time series of scan session day 1, RL, ** rfMRI_REST1_RL **,
# # parcellate the time series to Glasser 360 (hcp.parcellate(data, hcp.mmp)) and then adapte it to Schaefer
# # compute the functional connectivity matrix
#
# img = nib.load(datadir_day1+'100206'+'/MNINonLinear/Results/rfMRI_REST1_RL/rfMRI_REST1_RL_Atlas_MSMAll_hp2000_clean.dtseries.nii')
# data = img.get_fdata()
# data_parc = hcp.parcellate(data, hcp.mmp)
# data_sub = data_parc[:,360:]  # this is the subcortical regions parcels: include if you want 419x419 matrices
#
# img_cortex = data[:,hcp.struct.cortex] # cortex vertices
# node = [None]*400 # data_sub.shape[0] is time points. not all data has 1200 ts
#
# for i in range(400):
#     a = img_cortex[:,np.where(schaefer_400==i+1)][:,0]
#     ts = [None] * data_sub.shape[0]
#
#     for n in range(data_sub.shape[0]):
#         ts[n] = a[n].mean()
#         node[i] = ts
#
# # cortex parcels finished, now concatenate cortex and subcortex
# data_cor = np.array(node)
#
# # if you want matrices to include cortical and subcortical regions parcels, concatenate them here (so that in 419x419 matrices, the last 19 are subcortical parcels)
# #data_cor_sub = np.concatenate((data_cor,data_sub.T))
#
# # correlation
# corr_matrix_day1_RL_bianca = np.corrcoef(data_cor)  # use data_cor_sub if I want to include subcortical areas to yield 419x419 matrices
# pd.DataFrame(corr_matrix_day1_RL_bianca)

# %% [raw]
# ## Average functional connectivity and z-transform them across the 4 sessions

# %% [raw]
# # (across rfMRI_REST1_LR, rfMRI_REST1_RL, rfMRI_REST2_LR, rfMRI_REST2_RL)
#
# LR1_bianca = corr_matrix_day1_LR_bianca
# RL1_bianca = corr_matrix_day1_RL_bianca
# LR2_bianca = corr_matrix_day2_LR_bianca
# RL2_bianca = corr_matrix_day2_RL_bianca
#
# # average across four sessions
# mean_bianca = (LR1_bianca+RL1_bianca+LR2_bianca+RL2_bianca)/4
#
# # Fisher r to z transform
# fc_bianca = np.arctanh(mean_bianca)
# fc_bianca[fc_bianca == inf] = 0
# fc_bianca
# pd.DataFrame(fc_bianca)

# %% [raw]
# pd.DataFrame(mean_bianca)

# %% [raw]
# pd.DataFrame(corr_matrix_day2_LR_bianca)

# %% [raw]
# sub100206_sofie = pd.DataFrame(sub100206_sofie[0])
# sub100206_sofie
